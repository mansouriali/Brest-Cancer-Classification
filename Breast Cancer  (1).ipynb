# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import load_breast_cancer

# %%
#loading data from dataset
groups=load_breast_cancer()

# %%
#Creating a dataframe in order to analyze the data much better
df=pd.DataFrame(data=groups.data,columns=groups.feature_names)
df['label']=groups.target

# %%
#Top 5 observations
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
#Dataframe information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
#Dataframe statistical information
df.describe().transpose()
# Out:
#                          count        mean         std         min  \
# mean radius              569.0   14.127292    3.524049    6.981000
# mean texture             569.0   19.289649    4.301036    9.710000
# mean perimeter           569.0   91.969033   24.298981   43.790000
# mean area                569.0  654.889104  351.914129  143.500000
# mean smoothness          569.0    0.096360    0.014064    0.052630
# mean compactness         569.0    0.104341    0.052813    0.019380
# mean concavity           569.0    0.088799    0.079720    0.000000
# mean concave points      569.0    0.048919    0.038803    0.000000
# mean symmetry            569.0    0.181162    0.027414    0.106000
# mean fractal dimension   569.0    0.062798    0.007060    0.049960
# radius error             569.0    0.405172    0.277313    0.111500
# texture error            569.0    1.216853    0.551648    0.360200
# perimeter error          569.0    2.866059    2.021855    0.757000
# ...

# %%
#Separating features and labels

X=df.drop('label',axis=1)
y=df['label']

# %%
#names of features
X.columns
# Out:
# Index(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error', 'fractal dimension error',
#        'worst radius', 'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst compactness', 'worst concavity',
#        'worst concave points', 'worst symmetry', 'worst fractal dimension'],
#       dtype='object')

# %%
#names of labels (y)
groups.target_names
# Out:
# array(['malignant', 'benign'], dtype='<U9')

# %%
#Unique values of labels (y)
y.unique()
# Out:
# array([0, 1])

# %%
#Number of Class 1 (positive benign cases)
number_pos=(y==1).sum() 
number_pos
# Out:
# 357

# %%
#Number of Class 0 (negative malignant cases)
number_neg=(y==0).sum() 
number_neg
# Out:
# 212

# %%
#Balanced Classes
sns.countplot(x=y); 
plt.savefig('BC class distribution.jpg')

# %%
#positive percent cases
pos_percent=np.round(number_pos/len(y)*100,2)   
pos_percent
# Out:
# 62.74

# %%
#negative percent cases
neg_percent=np.round(number_neg/len(y)*100,2)   
neg_percent
# Out:
# 37.26

# %%
#Correlation between features and labels, sorted by values
plt.figure(figsize=(12,4),dpi=200)
df.corr()['label'].sort_values()[:-1].plot(kind='bar');
plt.savefig('BC corr ratings.jpg')

# %%
#creating a dataframe using top 5 correlated features with labels and visualize them,
#in order to find how they relate to each other
high_corr=pd.concat([df[df.corr()['label'].sort_values()[0:5].index],df['label']],axis=1)

# %%
sns.pairplot(data=high_corr,hue='label')
plt.savefig('top 5 correlated plot.jpg')

# %%
plt.figure(figsize=(6,6), dpi=150)
sns.heatmap(df.corr())
plt.savefig('Correlation Heatmap.jpg');

# %% [markdown]
# ### Important Note:
# As we can see, the datset has 569 samples with 30 features; its label is binary and relatively balanced. 62.74% are positive and 37.26 are negative cases.
# We assume that EDA has been done and we are ready to jump into the model training. We want to compare the performance of different classification algorithms including:
#
#     1) Support Vector Machine
#     2) Logistic Regression
#     3) Decision Tree
#     4) Random Forest
#     5) Gradient Boosting Tree
#
# The next steps are:
#
#     1) Dividing the data into Training and Testing sets(Train 85%-Test 15% split)
#     2) Scaling the data using StandardScaler
#     3) Defining the model and fitting the data; (Cross Validation will be used to find the best parameters)
#     4) Calculating the performance metrics

# %%
#Step1:
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# %%
#Step2:
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
#Step3:
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier

# %%
#Step3:
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# SVC Model

# %%
svc_model=SVC()

# %%
svc_param={'kernel':['rbf','linear'],
      'C':[0.01,0.1,0.5,.9,.99,1],
      'gamma':['scale','auto']}

# %%
svc_grid_model=GridSearchCV(svc_model,svc_param)

# %%
svc_grid_model.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.01, 0.1, 0.5, 0.9, 0.99, 1],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['rbf', 'linear']})

# %%
svc_best_model=svc_grid_model.best_estimator_

# %%
svc_best_model.get_params()
# Out:
# {'C': 0.1,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'linear',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %% [markdown]
# Logistic Regression Model

# %%
log_model=LogisticRegression()

# %%
log_model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
log_model.get_params()
# Out:
# {'C': 1.0,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 100,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# Decision Tree Model

# %%
tree_model=DecisionTreeClassifier()

# %%
tree_param={'criterion':['gini','entropy'],
            'max_depth':[3,4,5,6]}

# %%
tree_grid_model=GridSearchCV(tree_model,tree_param)

# %%
tree_grid_model.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 4, 5, 6]})

# %%
tree_best_model=tree_grid_model.best_estimator_

# %%
tree_best_model.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'entropy',
#  'max_depth': 3,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %% [markdown]
# Random Forest Model

# %%
rf_model=RandomForestClassifier()

# %%
rf_param={'n_estimators':[64,100,128],
         'max_features':['auto','sqrt','log2'],
         'bootstrap':[True,False]}

# %%
rf_grid_model=GridSearchCV(rf_model,rf_param)

# %%
rf_grid_model.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True, False],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [64, 100, 128]})

# %%
rf_best_model=rf_grid_model.best_estimator_

# %%
rf_best_model.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'log2',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 64,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# Gradient Boosting Tree Model

# %%
gbt_model=GradientBoostingClassifier()

# %%
gbt_param={'n_estimators':[64,100,128],
          'max_features':['auto','sqrt','log2'],
          'learning_rate':[0.1,0.5,1]}

# %%
gbt_grid_model=GridSearchCV(gbt_model,gbt_param)

# %%
gbt_grid_model.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=GradientBoostingClassifier(),
#              param_grid={'learning_rate': [0.1, 0.5, 1],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [64, 100, 128]})

# %%
gbt_best_model=gbt_grid_model.best_estimator_

# %%
gbt_best_model.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'friedman_mse',
#  'init': None,
#  'learning_rate': 1,
#  'loss': 'deviance',
#  'max_depth': 3,
#  'max_features': 'log2',
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_iter_no_change': None,
#  'random_state': None,
#  'subsample': 1.0,
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %%
#Step4:
from sklearn.metrics import classification_report,plot_confusion_matrix

# %%
#in order to make it easier to calculate the performance metrics, we create a function:
def performance_calculator(model,X_test,y_test):
    y_pred=model.predict(X_test)
    print(classification_report(y_test,y_pred))
    plot_confusion_matrix(model,X_test,y_test)

# %%
performance_calculator(svc_best_model,X_test,y_test)
plt.savefig('SVC report.jpg')
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        32
#            1       0.96      1.00      0.98        54
#
#     accuracy                           0.98        86
#    macro avg       0.98      0.97      0.97        86
# weighted avg       0.98      0.98      0.98        86

# %%
performance_calculator(log_model,X_test,y_test)
plt.savefig('logistic regression report.jpg')
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        32
#            1       0.96      1.00      0.98        54
#
#     accuracy                           0.98        86
#    macro avg       0.98      0.97      0.97        86
# weighted avg       0.98      0.98      0.98        86

# %%
performance_calculator(tree_best_model,X_test,y_test)
plt.savefig('Decision tree report.jpg')
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.93        32
#            1       0.93      1.00      0.96        54
#
#     accuracy                           0.95        86
#    macro avg       0.97      0.94      0.95        86
# weighted avg       0.96      0.95      0.95        86

# %%
performance_calculator(rf_best_model,X_test,y_test)
plt.savefig('random forest report.jpg')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94        32
#            1       0.95      0.98      0.96        54
#
#     accuracy                           0.95        86
#    macro avg       0.96      0.94      0.95        86
# weighted avg       0.95      0.95      0.95        86

# %%
performance_calculator(gbt_best_model,X_test,y_test)
plt.savefig('gradient boosting tree report.jpg')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.92        32
#            1       0.95      0.96      0.95        54
#
#     accuracy                           0.94        86
#    macro avg       0.94      0.93      0.94        86
# weighted avg       0.94      0.94      0.94        86

# %% [markdown]
# comparing the results, SVC and LogisticRegression achieve better performance.
# In different tree models, RandomForest has performed better.
